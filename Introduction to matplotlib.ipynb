# %% [markdown]
# # 3.Importing And Using Matplotlib

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4]);

# %%
plt.plot([3,9,1,5]);

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y);

# %%
# 1st method
fig=plt.figure() #creates a figure
ax=fig.add_subplot() # adds some axes
plt.show()

# %%
# 2nd method
fig=plt.figure() #creates a figure
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
# 3rd method
fig, ax=plt.subplots()
ax.plot(x, y);

# %% [markdown]
# # 4.Anatomy of A Matplotlib Figure

# %% [markdown]
# ### Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x=[1,2,3,4]
y=[11,22,33,44]

#2. Setup plot
fig, ax=plt.subplots(figsize=(10,10))

# 3. Plot data
ax.plot(x,y);

#4. Customize plot
ax.set(title="Simple Plot",
      xlabel="X-axis",
      ylabel="Y-axis")

# 5.Save $ show (you save the whole figure)
fig.savefig("images/sample-plot.png")

# %% [markdown]
# # 5.Scatter Plot and Bar Plot

# %% [markdown]
# # Making figures with Numpy Arrays
# We want:
#     * Line plot
#     * Scatter plot
#     * Bar plot
#     * Histogram
#     * Subplots

# %%
import numpy as np

# %%
# create some data
x=np.linspace(0,10,100)
x
# Return evenly spaced numbers over a specified interval
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
# plot the data
fig, ax=plt.subplots()
ax.plot(x,x**2);

# %%
# Use same data to make a scatter
fig, ax=plt.subplots()
ax.scatter(x,np.exp(x));

# %%
fig, ax=plt.subplots()
ax.scatter(x,x**2);

# %%
#Another scatter plot
fig, ax=plt.subplots(figsize=(8,8))
ax.scatter(x,np.sin(x));

# %%
nut_butter_prices={"Almond butter":10,
                   "Peanut butter":8,
                   "Cashew butter":12}

fig, ax=plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax.set(title="Nut's Butter Store",
      xlabel="Butter Names",
      ylabel="Prices($)");
#keys means almond butter peanut butter and cashew butter but values means numbers

# %%
fig, ax=plt.subplots()
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
#Make some data for hisograms and plot it
x=np.random.randn(1000)
fig, ax=plt.subplots()
ax.hist(x);

# %% [markdown]
# ## two option for subplots

# %%
# Sub plots option 1
fig, ((ax1,ax2), (ax3,ax4))=plt.subplots(nrows=2,
                                        ncols=2,
                                      figsize=(10,6))
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax4.hist(np.random.randn(1000));

# %% [markdown]
# # 7.Subplots option 2

# %%
# subplot option 2
fig, ax=plt.subplots(nrows=2,
                    ncols=2,
                figsize=(10,6))
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10),np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# # 9. Plotting from pandas DataFrames

# %%
import pandas as pd

# %%
#Make a dataframe
car_sales=pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts= pd.Series(np.random.randn(1000),
             index=pd.date_range("1/1/2020",periods=1000))
ts=ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:>

# %%
ts=pd.Series(np.random.randn(1000),
           index=pd.date_range("1/1/2020",periods=1000) )
ts=ts.cumsum()
ts.plot();

# %% [markdown]
# # 11.Plotting from pandas DataFrame

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"]=car_sales["Price"].str.replace("[\$\,\.]","")
car_sales
# Out:
# /tmp/ipykernel_6241/1325740940.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"]=car_sales["Price"].str.replace("[\$\,\.]","")
#      Make Colour  Odometer (KM)  Doors     Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales["Price"])
# Out:
# pandas.core.series.Series

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
# Remove last two zeros
car_sales["Price"]=car_sales["Price"].str[:-3]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"]=pd.date_range("1/1/2020",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
# Since price column's data are string so it added one string after another
# now first we need to change price data types into integer
car_sales["Total Sales"]=car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  \
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10
#
#                                  Total Sales
# 0                                       4000
# 1                                   40005000
# 2                               400050007000
# 3                          40005000700022000
# 4                      400050007000220003500
# 5                  4000500070002200035004500
# ...

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
car_sales["Total Sales"]=car_sales["Price"].astype(int).cumsum()
car_sales
# here we took the price data as an integer
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x="Sale Date", y="Total Sales")
# Out:
# <AxesSubplot:xlabel='Sale Date'>

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
# here we changed price column into integer
car_sales["Price"]=car_sales["Price"].astype(int)

# %%
type(car_sales["Price"][0])
# Out:
# numpy.int64

# %% [markdown]
# # 12.Plotting from Pandas DataFrames

# %%
x=np.random.rand(10,4)
x
#turn it in to dataframes
df=pd.DataFrame(x,columns=["a","b","c","d"])
df
# Out:
#           a         b         c         d
# 0  0.910798  0.335632  0.263884  0.481804
# 1  0.030556  0.418981  0.796139  0.440360
# 2  0.782339  0.015281  0.528364  0.013248
# 3  0.931430  0.940408  0.173184  0.492449
# 4  0.152757  0.665719  0.081973  0.725186
# 5  0.424930  0.551434  0.566603  0.831151
# 6  0.842971  0.158416  0.845927  0.311183
# 7  0.084023  0.601536  0.703061  0.823080
# 8  0.346426  0.234420  0.317184  0.883699
# 9  0.312333  0.992093  0.770828  0.656566

# %%
df.plot.bar(figsize=(8,8))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x="Make",y="Odometer (KM)",kind="bar",figsize=(8,6))
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
# Histograms
# Histograms are great for visualing distributions

# %%
car_sales["Odometer (KM)"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=20);

# %% [markdown]
# # 13. Plotting from Pandas DataFrames 4

# %%
# Trying on another data set
heart_disease=pd.read_csv("11.3 heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot.hist(bins=10);

# %%
heart_disease.plot.hist(figsize=(10,30),subplots=True);

# %% [markdown]
# # 14. Plotting from Pandas DataFrames 5

# %% [markdown]
# ### Which one should you use? (pyplot vs matplotlib OO method ?)
# * When plotting something very quickly,  okay to use the pyplot method
# * When plotting something more advanced, use the OO method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50=heart_disease[heart_disease["age"]>50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
len(over_50)
# Out:
# 208

# %%
# pyplot method
over_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target",
            figsize=(10,7));

# %%
# OO method mixed with pyplot

fix, ax=plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target",
            ax=ax);
# ax.set_xlim([45,100]); this is to set x limitations

# %% [markdown]
# # 15. Plotting from Pandas DataFrame 6

# %%
## OO(Object Oriented) method from Scratch
fig, ax=plt.subplots(figsize=(10, 6))

# plot the data
scatter=ax.scatter(x=over_50["age"],
                  y=over_50["chol"],
                  c=over_50["target"]);
#customize the plot
ax.set(title="Heart Disease and Cholestrol Levels",
      xlabel="Age",
      ylabel="Cholestrol");
# Add a legend
#legend elements gets from the c parameter
ax.legend(*scatter.legend_elements(),title="Title")

# Add a horizontal line
ax.axhline(over_50["chol"].mean(),
          linestyle="--");

# %% [markdown]
# # 16.Plotting from Pandas DataFrames

# %%
# Subplots of chol, age,thal
fig, (ax0,ax1)=plt.subplots(nrows=2,
                           ncols=1,
                           figsize=(10,10));
# Add data to ax0
scatter=ax0.scatter(x=over_50["age"],
                   y=over_50["chol"],
                   c=over_50["target"]);

#customize ax0
ax0.set(title="Heart Disease and Cholestrol Levels",
       xlabel="Age",
       ylabel="Cholestrol");
# Add a legend to ax0
ax0.legend(*scatter.legend_elements(),title="Target");
# Add a meanline
ax0.axhline(y=over_50["chol"].mean(),
           linestyle="dotted");
# Add data to ax1
scatter=ax1.scatter(x=over_50["age"],
                   y=over_50["thalach"],
                   c=over_50["target"]);
# Customize ax1
ax1.set(title="Heart Disease And Max Heart Rate",
       xlabel="Age",
       ylabel="Max Heart Rate");
#Add a legend to ax1
ax1.legend(*scatter.legend_elements(),title="Target")
# Add a meanline
ax1.axhline(y=over_50["thalach"].mean(),
           linestyle="--");
#Add a title to the figure

fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold");

# %% [markdown]
# # 17. Customize your plot

# %%
# see the different styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-whitegrid');

# %%
car_sales["Price"].plot();

# %%
plt.style.use("seaborn");

# %%
car_sales["Price"].plot();

# %%
car_sales.plot(x="Odometer (KM)",y="Price", kind="scatter");

# %%
plt.style.use('ggplot')
car_sales["Price"].plot();

# %%
x=np.random.randn(10,4)
x
# Out:
# array([[-0.55394101, -0.28683432, -0.26094481,  2.43056647],
#        [ 0.21210142,  1.39218575,  0.40709116, -0.13889001],
#        [ 0.39008143,  0.52707978, -0.14621917, -0.51933612],
#        [-1.97724154, -0.1182281 ,  0.08884741, -0.95643354],
#        [-0.94628325, -0.30869131, -1.54282774, -0.65007581],
#        [ 0.6400452 , -0.553633  ,  0.54992764,  0.46129163],
#        [ 0.71439443,  1.29387468,  0.08742666,  0.26503655],
#        [ 0.09180719,  2.11021529,  0.82248287,  0.14968095],
#        [ 0.32695313,  0.07510367, -0.56343632,  1.22262102],
#        [ 1.26671029, -0.53466409,  0.59332007,  1.51876252]])

# %%
df=pd.DataFrame(x,columns=["a","b","c","d"])
df
# Out:
#           a         b         c         d
# 0 -0.553941 -0.286834 -0.260945  2.430566
# 1  0.212101  1.392186  0.407091 -0.138890
# 2  0.390081  0.527080 -0.146219 -0.519336
# 3 -1.977242 -0.118228  0.088847 -0.956434
# 4 -0.946283 -0.308691 -1.542828 -0.650076
# 5  0.640045 -0.553633  0.549928  0.461292
# 6  0.714394  1.293875  0.087427  0.265037
# 7  0.091807  2.110215  0.822483  0.149681
# 8  0.326953  0.075104 -0.563436  1.222621
# 9  1.266710 -0.534664  0.593320  1.518763

# %%
ax=df.plot(kind="bar")
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
#customize our plot with the set() method
ax=df.plot(kind="bar")
#Add some labels and a title
ax.set(title="Random Number Bar Graph from DataFrame",
      xlabel="Row Number",
      ylabel="Random Number")
# Make the legend visible
ax.legend().set_visible(True)

# %% [markdown]
# # 18.Customizing ur plots 2

# %%
# Set style
plt.style.use("seaborn-whitegrid") 
## OO(Object Oriented) method from Scratch
fig, ax=plt.subplots(figsize=(10, 6))

# plot the data
scatter=ax.scatter(x=over_50["age"],
                  y=over_50["chol"],
                  c=over_50["target"],
                  cmap="winter"); ##this changes the colour scheme
#customize the plot
ax.set(title="Heart Disease and Cholestrol Levels",
      xlabel="Age",
      ylabel="Cholestrol");
# Add a legend
#legend elements gets from the c parameter
ax.legend(*scatter.legend_elements(),title="Title")

# Add a horizontal line
ax.axhline(over_50["chol"].mean(),
          linestyle="--");

# %%
#Customizing the y and x axis limitations

# Subplots of chol, age,thal
fig, (ax0,ax1)=plt.subplots(nrows=2,
                           ncols=1,
                           figsize=(10,10));
# Add data to ax0
scatter=ax0.scatter(x=over_50["age"],
                   y=over_50["chol"],
                   c=over_50["target"],
                   cmap="winter");

#customize ax0
ax0.set(title="Heart Disease and Cholestrol Levels",
       xlabel="Age",
       ylabel="Cholestrol");
#Change the x axis limits
ax0.set_xlim([50,80])
ax0.set_ylim([100,450])
# Add a legend to ax0
ax0.legend(*scatter.legend_elements(),title="Target");
# Add a meanline
ax0.axhline(y=over_50["chol"].mean(),
           linestyle="dotted");
# Add data to ax1
scatter=ax1.scatter(x=over_50["age"],
                   y=over_50["thalach"],
                   c=over_50["target"],
                   cmap="winter");
# Customize ax1
ax1.set(title="Heart Disease And Max Heart Rate",
       xlabel="Age",
       ylabel="Max Heart Rate");
#Change ax1 axis limits

ax1.set_xlim([50,80])
ax1.set_ylim([60,200])
#Add a legend to ax1
ax1.legend(*scatter.legend_elements(),title="Target")
# Add a meanline
ax1.axhline(y=over_50["thalach"].mean(),
           linestyle="--");
#Add a title to the figure

fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold");

# %%
# Save figure
fig.savefig("Heart-disease-analysis-saved-image.png")
